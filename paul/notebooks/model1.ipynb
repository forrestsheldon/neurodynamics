# %% [markdown]
# # "Model 1"

# %% [markdown]
# *Reference:* H. Sompolinsky, A. Crisanti. *Chaos in random neural networks.* PRL **61**(3) 259, 1988. (doi: 10.1103/PhysRevLett.61.259)

# %% [markdown]
# ---

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation
from scipy.integrate import odeint

# %%
# %matplotlib tk
# Out:
# Warning: Cannot change to a different GUI toolkit: tk. Using gtk instead.

# %%
# %matplotlib inline

# %%
# seed random number generator
np.random.seed(2)

# %% [markdown]
# Connectivity options + initial state

# %%
# random connectivities
structure = 'none'
M = 8  # number of rows
N = 8  # number of columns

Jvar = 0.7
J = np.sqrt(Jvar) * np.random.randn(M*N,M*N)

for i in range(M*N):
    J[i,i] = 0.0

# randomly draw initial state
x = np.array(np.random.randn(M*N))
# instead use x on the limit cycle found in one set of experiments
#x = np.load('limitcycle_x0.npy')

# %%
print x
# Out:
# [ 0.69950122  0.05126074 -2.23875015  0.27788725  0.51091477  0.09535203
#   0.16595919  1.92705429  1.39425116  0.17567278 -1.80921751 -0.2268956
#  -1.33720947 -0.61087065 -1.1459258   0.68713928  0.37496512 -0.99929957
#   1.52400588 -0.06843398  1.2066603   1.06385037  1.36029333  1.51460821
#  -1.35660912 -0.65674159  0.40597466  0.5993913   0.39028745  1.40883726
#  -0.22375858  1.68828363  0.53155876  0.66965014  1.32919453 -1.46232733
#   0.35238154 -0.34696965  1.29382752 -0.12301795 -0.92584967  0.1218021
#  -1.64073835 -0.07920889 -0.37276631 -2.56024329 -0.87910096  0.15293701
#  -1.43462749 -0.04465373 -1.44020229 -0.64230604  0.08239974  0.70576891
#   0.10005687  0.39180231 -0.19848617 -0.15620584  0.39169691  0.17866686
#   0.24718746 -0.28908929  0.2890849   0.16157295]

# %%
print J
# Out:
# [[ 0.         -0.04707621 -1.78726988 ..., -0.1107143  -0.03310684
#    0.27275404]
#  [-1.70705674  0.         -0.56698407 ...,  1.05637838  0.62913893
#   -0.83144009]
#  [ 0.92797585 -1.47663611  0.         ...,  0.52058695  0.80384785
#    0.63449815]
#  ...,
#  [-0.62661088  0.77958671 -0.28495939 ...,  0.         -0.26331114
#   -0.83803028]
#  [ 1.43868897  0.76272145 -0.04292309 ...,  1.41401995  0.         -1.13668727]
#  [ 0.55194008  0.43348194  0.28464798 ..., -0.29163496 -0.3632735   0.        ]]

# %%
# nearest-neighbor interactions (rectangular grid structure, periodic boundary conditions)
structure = 'rect_periodic'
M = 4  # number of rows
N = 4  # number of columns

# uniform connection strength
Jm = 1.0

J = np.zeros(shape=(M*N,M*N))
for ns in range(M*N):
    # get index numbers of neighbors
    iL = ns - 1
    iR = ns + 1
    iT = ns - N
    iB = ns + N
    
    # now modify edge oscillators to enforce periodic boundary conditions
    if ns%N == 0:  # left-hand edge
        iL = ns + N - 1
    if ns%N == (N-1):  # right-hand edge
        iR = ns - N + 1
    if ns < N:  # top edge
        iT = ns + N*(M-1)
    if ns > (N*M - 1 - N):  # bottom edge
        iB = (ns%N)
    
    # fill in connection strenghts
    J[ns,iL] = Jm
    J[ns,iR] = Jm
    J[ns,iT] = Jm
    J[ns,iB] = Jm

# initialize the state
x = np.array(np.random.randn(M*N))

# %%
# equations of motion
g = 1.0
def dxdt(x, t):
    return -x + np.einsum('ij,j', J, np.tanh(g*x))

# %% [markdown]
# Run the simulation, collect time series data

# %%
t0 = 0.0
tf = 20000.0
dt = 0.1
times = np.arange(t0, tf+dt, dt)

sol = odeint(dxdt, x, times)
x = sol[-1]

# %%
plt.subplot(5,1,1)
plt.plot(times, np.tanh(g*sol.T[0]))
plt.subplot(5,1,2)
plt.plot(times, np.tanh(g*sol.T[3]))
plt.subplot(5,1,3)
plt.plot(times, np.tanh(g*sol.T[1]))
plt.subplot(5,1,4)
plt.plot(times, np.tanh(g*sol.T[12]))
plt.subplot(5,1,5)
plt.plot(times, np.tanh(g*sol.T[4]))

plt.show()

plt.subplot(5,1,1)
plt.plot(times, sol.T[0])
plt.subplot(5,1,2)
plt.plot(times, sol.T[1])
plt.subplot(5,1,3)
plt.plot(times, sol.T[2])
plt.subplot(5,1,4)
plt.plot(times, sol.T[3])
plt.subplot(5,1,5)
plt.plot(times, sol.T[4])

plt.show()

# %%
plt.plot(sol.T[0],sol.T[1])
#plt.show()
#plt.savefig('ipynb_figs/exp3_attractor.pdf')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(sol.T[0],sol.T[1],sol.T[2])
#plt.show()
#fig.savefig('ipynb_figs/exp3_attractor_3d.pdf')

# %% [markdown]
# Animating the simulation (useless, fun)

# %%
# solve and animate the bastard
t0 = 0.0
tf = 100.0
dt = 0.1
times = np.arange(t0, tf+dt, dt)

# extract geometrical structure
if structure == 'none':
    geo = (M,N)
elif structure == 'rect_periodic' or structure == 'rect_edges':
    geo = (M,N)
else:
    print 'Youre fucked'
    exit(0)

# initialize the figure object
fig = plt.figure()
ax = plt.axes()
im = ax.imshow(x.reshape(geo), cmap=plt.get_cmap('gray'), interpolation='none')
im.set_clim(None)

# time evolution of system, also fed to animation function
i = 0
def update_fig(*args):
    global x
    
    x = odeint(dxdt, x, (times[i],times[i+1]))[-1]
    #im.set_array(np.tanh(g*x).reshape(geo))
    im.set_array(x.reshape(geo))
    return im,

ani = animation.FuncAnimation(fig, update_fig, blit=False)
plt.show()
